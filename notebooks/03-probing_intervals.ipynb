# %% [markdown]
# # Probing Intervals

# %%
# TODO:

# datasets:
# - ipid.nec.rt.base
# - ipid.nec.fi.base

# Compute delta of SEND_TIMESTAMP_SEQUENCE for both datasets
# Plot with "Probing Interval [ms]" by "Continent (#IP Addr.)"

# %%
# Input
zmap = "icmp_2026-07-10_10-34-14"
rt_base = "icmp_2026-07-10_11-13-08"
fi_base = "icmp_2026-07-10_11-14-08"

# %%
from ipid_analysis.probing_intervals import main

info, fig = main(zmap, rt_base, fi_base)
# Out:
# 2026-07-14 03:03:04.333 | INFO     | ipid_analysis.config:<module>:16 - PROJ_ROOT path is: F:\GitHub\ipid-analysis
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from ipid_analysis.probing_intervals import main
# ----> 3 info, plt = main(rt_base, fi_base, output_id)
#
# NameError: name 'fi_base' is not defined
