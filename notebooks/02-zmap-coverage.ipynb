# %% [markdown]
# # ZMap Coverage

# %% [markdown]
# # Input

# %%
raw_measurement_id = "tcp-80_YYYY-MM-DD_HH-MM-SS"

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import json

from ipid_analysis.analyze_coverage import create_info
from ipid_analysis.config import load_measurement_id

measurement_id = load_measurement_id(raw_measurement_id)

# %% [markdown]
# ## Compute

# %%
info = create_info(measurement_id)
print(json.dumps(info, indent=2))
