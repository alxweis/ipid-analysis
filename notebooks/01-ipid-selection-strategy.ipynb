# %% [markdown]
# # IPID Selection-Strategy Distribution

# %% [markdown]
# ## Input

# %%
measurement = "ipid/tcp-80_YYYY-MM-DD_HH-MM-SS"

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
from ipid_analysis.plots import strategy_distribution, plot_strategy_distribution, info_strategy_distribution

counts, total, percentages = strategy_distribution(measurement)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Distribution

# %%
info = info_strategy_distribution(measurement, counts, total, percentages)
print(json.dumps(info, indent=2))

# %% [markdown]
# ## Plot

# %%
plot, plot_path = plot_strategy_distribution(measurement, percentages)
print(f"figure saved -> {plot_path}")
